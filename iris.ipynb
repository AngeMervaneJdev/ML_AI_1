# %% [markdown]
# <a href="https://colab.research.google.com/github/AngeMervaneJdev/ML_AI_1/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import numpy as  np
import pandas as pd
data = load_iris()
 

Y=data.target
X=data.data


dfX=pd.DataFrame(data=X,columns=["sepal_length","sepal_width","petal_length","petal_width"])
dfY=pd.DataFrame(data=Y,columns=["Species"])

print(dfX)
print(dfY)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %%
print("Probleme 2\n")

df=pd.concat([dfX,dfY],axis=1)
print(df)
# Out:
# Probleme 2
#
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
print("Probleme 3\n")
print("la 4eme ligne")
print(df.head(4).iloc [-1:].info())
print('*'*100)
print("\nOutput the total number of samples for each label.\n")
print(df.groupby("Species").sum())
print('*'*100)
print("\n\nCheck if there is a missing value in the feature quantity.\n")
print(df.isnull().sum(axis=0))
print('*'*100)
print("\n\nOutput the total number of samples for each label.\n")
print(df.value_counts(sort=True))
print('*'*100)
print("\n\n Moyenne quartiles ecart types\n")
print(df.describe())
# Out:
# Probleme 3
#
# la 4eme ligne
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 3 to 3
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  1 non-null      float64
#  1   sepal_width   1 non-null      float64
#  2   petal_length  1 non-null      float64
#  3   petal_width   1 non-null      float64
#  4   Species       1 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 172.0 bytes
# None
# ****************************************************************************************************
#
# Output the total number of samples for each label.
#
#          sepal_length  sepal_width  petal_length  petal_width
# Species
# 0               250.3        171.4          73.1         12.3
# 1               296.8        138.5         213.0         66.3
# 2               329.4        148.7         277.6        101.3
# ...

# %% [markdown]
# Probleme 4
#
# Utilisé à l'origine comme exemple pour l'application de l'analyse linéaire discriminante de Fisher, ce jeu de données est devenu un cas typique pour de nombreuses techniques de classification automatique en apprentissage automatique (machine learning) tel que les machines à vecteurs de support (SVM).
#
# l'ensemble de données d'iris se composent de 3 types différents d'iris (Setosa, Versicolor et Virginica) de longueur de pétale et de sépale, stockés dans un numpy.ndarray 150x4

# %%
print("Probleme 5\n")

print("extract sepal\n")
print(df.sepal_width)
print(df["sepal_width"])
print(df.iloc[:,1])

print(df.iloc[50:,:99])
print(df.iloc[50:,:99].sepal_width)
print('*'*100,end="\n")
print(df.loc[df.sepal_width==2.0,])
# Out:
# Probleme 5
#
# extract sepal
#
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 50            7.0          3.2           4.7          1.4        1
# 51            6.4          3.2           4.5          1.5        1
# 52            6.9          3.1           4.9          1.5        1
# 53            5.5          2.3           4.0          1.3        1
# ...

# %%
print("Probleme 6\n")
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=1, rc={'figure.figsize':(6, 5)})


df.Species.value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,8))
plt.show()
plt.clf()
fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot(y="petal_width",x="Species",data=df, orient='v', ax=axes[0, 0])
sns.boxplot(y="petal_length",x="Species",data=df, orient='v', ax=axes[0, 1])
sns.boxplot(y="sepal_length",x="Species",data=df, orient='v', ax=axes[1, 0])
sns.boxplot(y="sepal_length",x="Species",data=df, orient='v', ax=axes[1, 1])
plt.show()

plt.clf()
fig, axes =plt.subplots(2, 2,figsize=(16,9))
sns.violinplot(y="petal_width",x= "Species", data=df,  orient='v' , ax=axes[0, 0])
sns.violinplot(y="petal_length",x= "Species", data=df,  orient='v' , ax=axes[0, 1])
sns.violinplot(y="sepal_length",x= "Species", data=df,  orient='v' , ax=axes[1, 0])
sns.violinplot(y="sepal_length",x= "Species", data=df,  orient='v' , ax=axes[1, 1])
plt.show()
# Out:
# Probleme 6

# %%
print("Probleme 7\n")
sns.pairplot(df,hue="Species")

print(df.corr())

plt.figure(figsize=(7,4))
sns.heatmap(df.corr(),annot=True,cmap='summer')
# Out:
# Probleme 7
#
#               sepal_length  sepal_width  petal_length  petal_width   Species
# sepal_length      1.000000    -0.117570      0.871754     0.817941  0.782561
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126 -0.426658
# petal_length      0.871754    -0.428440      1.000000     0.962865  0.949035
# petal_width       0.817941    -0.366126      0.962865     1.000000  0.956547
# Species           0.782561    -0.426658      0.949035     0.956547  1.000000

# %% [markdown]
# Probleme 8
#
#  Seule une petite partie des Iris virginica est mélangée avec les Iris versicolor (les nœuds à la fois bleus et verts sur le diagramme). Par conséquent, les trois espèces d'iris (Iris setosa, Iris virginica et Iris versicolor) sont séparables grâce à une analyse en composantes principales non linéaire. Pour les distinguer, il suffit simplement de sélectionner les nœuds correspondant sur l'arbre principal.
